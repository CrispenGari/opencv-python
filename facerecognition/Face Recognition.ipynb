# %% [markdown]
# # Face Recognition
# * Recognize and manipulate faces from Python or from the command line with the world’s simplest face recognition library.
# * The model has an accuracy of 99.38% on the [Labeled Faces](http://vis-www.cs.umass.edu/lfw/) in the Wild benchmark.

# %% [markdown]
# ### Instalation

# %%
# !pip install face-recognition
# Out:
# ...
#   Using cached dlib-19.22.0.tar.gz (7.4 MB)
# ...
#   Created wheel for dlib: filename=dlib-19.22.0-cp38-cp38-win_amd64.whl size=3011758 sha256=2f2985a2488ad553c4bad158ae49dd62841852f9f693cc46f4c070724d1cbe61
#   Stored in directory: c:\users\crisp\appdata\local\pip\cache\wheels\80\93\82\7b6b3974475c898a823b58a6c0b87013f0782095d43b910e64
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=bc2e22b8494cfac3ecd1b57ea95f8f663d806589163cb75ad6fb7966718af779
#   Stored in directory: c:\users\crisp\appdata\local\pip\cache\wheels\b4\4b\8f\751e99d45f089bdf366a7d3e5066db3c2b84a62e4377f534d7
# Successfully built dlib face-recognition-models
# ...

# %%
## Imports

# %%
import face_recognition as fr
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Loading the file

# %%
image = fr.load_image_file('images/obama.jpg')

# %% [markdown]
# ### Finding the faces in the picture
# * First we will try to find the faces in the picture
# * using image-ROI we will extract the faces from the image

# %%
face_locations = fr.face_locations(image)
face_locations
# Out:
# [(170, 740, 491, 419)]

# %%
image = cv2.imread('images/obama.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show()

# %%
face_locations[0][:2]
# Out:
# (170, 740)

# %%
## Getting Face Landmarks

# %%
image = fr.load_image_file('images/obama.jpg')
landmarks = fr.face_landmarks(image)
landmarks
# Out:
# [{'chin': [(448, 271),
#    (449, 309),
#    (453, 347),
#    (461, 385),
#    (474, 422),
#    (494, 456),
#    (521, 485),
#    (552, 507),
#    (589, 513),
#    (628, 506),
#    (660, 482),
#    (688, 450),
#    (710, 417),
#    (722, 382),
#    (729, 344),
#    (733, 307),
#    (734, 270)],
#   'left_eyebrow': [(477, 250), (494, 230), (521, 221), (548, 221), (576, 228)],
#   'right_eyebrow': [(617, 227),
#    (642, 219),
#    (670, 218),
#    (696, 228),
#    (710, 250)],
#   'nose_bridge': [(596, 253), (597, 278), (597, 302), (597, 328)],
#   'nose_tip': [(558, 343), (576, 347), (595, 352), (613, 346), (631, 342)],
#   'left_eye': [(508, 262),
#    (524, 252),
#    (541, 251),
#    (556, 261),
#    (540, 262),
#    (524, 263)],
#   'right_eye': [(633, 260),
#    (650, 250),
#    (667, 251),
#    (681, 260),
#    (666, 263),
#    (650, 262)],
#   'top_lip': [(520, 387),
#    (545, 376),
#    (574, 373),
#    (594, 377),
#    (615, 373),
#    (641, 375),
#    (665, 383),
# ...

# %%
### Identify faces in pictures
* Recognize who appears in each photo.

# %%
import face_recognition
known_image = face_recognition.load_image_file("images/biden.jpg")
unknown_image = face_recognition.load_image_file("images/biden.jpg")

biden_encoding = face_recognition.face_encodings(known_image)[0]
unknown_encoding = face_recognition.face_encodings(unknown_image)[0]

results = face_recognition.compare_faces([biden_encoding], unknown_encoding)

# %%
results
# Out:
# [True]

# %%
import face_recognition
import cv2
import numpy as np

# %%
video_capture = cv2.VideoCapture(0)

# %%
obama_image = face_recognition.load_image_file("images/obama.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# %%
biden_image = face_recognition.load_image_file("images/biden.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# %%
crispen_image = face_recognition.load_image_file("images/me (2).jpg")
crispen_face_encoding = face_recognition.face_encodings(biden_image)[0]

# %%
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding,
    crispen_face_encoding
]
known_face_names = [
    "Barack Obama",
    "Joe Biden",
    "Crispen Gari"
]
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True
